# %%
a=10
b=15
s=a+b
sub=a-b
m=a*b
d=a/b
p=a**b
print(f"{a} + {b} + {s} + {sub} + {m} + {d} + {p}")
# Out:
# 10 + 15 + 25 + -5 + 150 + 0.6666666666666666 + 1000000000000000

# %% [markdown]
# Aprendendo Py
# Comando e conseitos basicos
